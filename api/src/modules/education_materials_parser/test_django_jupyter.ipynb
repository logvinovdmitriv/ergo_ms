# %%
import os
import re
import time
import requests

from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
from datetime import datetime

import os, sys
import django
PROJECTPATH = 'C:/projects/ergo_ms/api'
sys.path.insert(0, PROJECTPATH)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "src.config.patterns.development")
os.chdir(PROJECTPATH)
django.setup()

from src.modules.education_materials_parser.fgos.models import *

class FgosParser:
    """Парсер для сбора документов ФГОС с сайта fgos.ru"""
    
    def __init__(self):
        self.base_url = "https://fgos.ru"
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        self.session = requests.Session()
        self.session.headers.update(self.headers)
        
        # Текущая сессия парсинга
        self.parsing_session = None

    def get_page_content(self, url, timeout=30):
        """Получить содержимое страницы"""
        try:
            response = self.session.get(url, timeout=timeout)
            response.raise_for_status()
            return response.text
        except requests.exceptions.RequestException as e:
            print(f"Ошибка при получении страницы {url}: {e}")
            return None

FgosParser().get_page_content("https://fgos.ru/fgos/fgos-01-06-01-matematika-i-mehanika-uroven-podgotovki-kadrov-vysshey-kvalifikacii-866/")
# Out:
# [INFO] config.database: Успешное тестовое подключение к базе данных 'default' (тип: django.db.backends.postgresql)
# ...
